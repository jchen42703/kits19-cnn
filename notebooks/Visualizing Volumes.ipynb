# %% [markdown]
# # Visualizing the Data
# This notebooks uses [`ipyvolume`](https://github.com/maartenbreddels/ipyvolume)
# To install: (make sure you have [`jupyter_contrib_nbextensions`](https://github.com/ipython-contrib/jupyter_contrib_nbextensions) installed)
# i.e.
# ```
# conda install -c conda-forge jupyter_contrib_nbextensions
# ```
#
# ```
# conda install -c conda-forge ipyvolume OR pip install ipyvolume
# jupyter nbextension enable --py --sys-prefix ipyvolume
# jupyter nbextension enable --py --sys-prefix widgetsnbextension
# ```
# * Holes in volume
#     * patients 0-3, 7, 9, 14...

# %% [markdown]
# # Raw Interpolated

# %%
import os
import nibabel as nib

dset_dir = r"C:\Users\jchen\Desktop\Datasets\kits19\data"
i = 14
case = f"case_000{i}"
image = nib.load(os.path.join(dset_dir, case, "imaging.nii.gz")).get_fdata().squeeze()
mask = nib.load(os.path.join(dset_dir, case, "segmentation.nii.gz")).get_fdata().squeeze()

print(f"Case: {case}; Shape: {image.shape}")
assert mask.shape == image.shape
# Out:
# Case: case_00014; Shape: (146, 556, 556)

# %%
print(nib.load(os.path.join(dset_dir, case, "imaging.nii.gz")).affine)
# Out:
# [[ 0.          0.         -0.78162497  0.        ]
#  [ 0.         -0.78162497  0.          0.        ]
#  [-3.          0.          0.          0.        ]
#  [ 0.          0.          0.          1.        ]]

# %%
import ipyvolume as ipv
ipv.quickvolshow(mask)
# Out:
# C:\Users\jchen\Miniconda3\envs\py36\lib\site-packages\ipyvolume\widgets.py:179: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data_view = self.data_original[view]
# C:\Users\jchen\Miniconda3\envs\py36\lib\site-packages\ipyvolume\utils.py:204: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data = (data[slices1] + data[slices2])/2
# C:\Users\jchen\Miniconda3\envs\py36\lib\site-packages\ipyvolume\serialize.py:81: RuntimeWarning: invalid value encountered in true_divide
# ...

# %% [markdown]
# ## Preprocessed

# %%
import os
import numpy as np

dset_dir = r"C:\Users\jchen\Desktop\Datasets\kits_preprocessed_isensee_spacing"
case = f"case_000{i}"
image = np.load(os.path.join(dset_dir, case, "imaging.npy")).squeeze()
mask = np.load(os.path.join(dset_dir, case, "segmentation.npy")).squeeze()

print(f"Case: {case}; Shape: {image.shape}")
assert mask.shape == image.shape
# Out:
# Case: case_00014; Shape: (136, 268, 268)

# %%
import ipyvolume as ipv
ipv.quickvolshow(mask)

# %% [markdown]
# # Predictions

# %%
# ...
